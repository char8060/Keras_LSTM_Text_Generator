# %%
import nltk
import numpy as np
import os
import random
import sys
import tensorflow as tf

# %%
# Download NLTK model data (you need to do this once)
#DONE
#nltk.download("book")

# %%
corpora_dir = "/Users/char8060/datascience/nltk_data/corpora/state_union"

# Read all file paths in corpora directory
file_list = []
for root, _ , files in os.walk(corpora_dir):  
    for filename in files:
        file_list.append(os.path.join(root, filename))
        
print("Read ", len(file_list), " files..." )

# Extract text from all documents
docs = []

for files in file_list:
    with open(files, 'r') as fin:
        try:
            str_form = fin.read().lower().replace('\n', '')
            docs.append(str_form)
        except UnicodeDecodeError: 
            # Some sentences have wierd characters. Ignore them for now
            pass
# Combine them all into a string of text
text = ' '.join(docs)

print('corpus length:', len(text))
# Out:
# Read  66  files...
# corpus length: 1915949

# %%
chars = sorted(list(set(text)))
print('Total Number of Unique Characters:', len(chars))
char_indices = dict((c, i) for i, c in enumerate(chars)) # Character to index
indices_char = dict((i, c) for i, c in enumerate(chars)) # Index to Character
# Out:
# Total Number of Unique Characters: 57

# %%
"""
Recommended to run this script on GPU, as recurrent
networks are quite computationally intensive.
If you try this script on new data, make sure your corpus
has at least ~100k characters. ~1M is better.
"""

# cut the text in semi-redundant sequences of maxlen characters
maxlen = 40 # Number of characters considered
step = 3 # Stide of our window
sentences = []
next_chars = []

# Reading the text in terms of sequence of characters
# Extract only 'maxlen' characters every time
for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    # The character just after the sequence is the label
    next_chars.append(text[i + maxlen]) 
print('nb sequences:', len(sentences))

print('Vectorization...')
# Initializing Tensor (training data)
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool) 
# Initializing Output that holds next character (label)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool) 
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        # Populate Tensor Input
        x[i, t, char_indices[char]] = 1 
    # Populate y with the character just after the sequence
    y[i, char_indices[next_chars[i]]] = 1


def sample(preds, temperature=1.0):
    """Perform Temperature Sampling"""
    # helper function to sample an index from a probability array
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature 
    exp_preds = np.exp(preds)
    # Softmax of predictions
    preds = exp_preds / np.sum(exp_preds) 
    # Sample a single characters, with probabilities defined in `preds`
    probas = np.random.multinomial(1, preds, 1) 
    return np.argmax(probas)


def on_epoch_end(epoch, _):
    """Function invoked at end of each epoch. Prints generated text"""
    print()
    print('----- Generating text after Epoch: %d' % epoch)

    start_index = random.randint(0, len(text) - maxlen - 1)
    for diversity in [0.2, 0.5, 1.0, 1.2]:
        print('----- Diversity:', diversity)

        generated = ''
        sentence = text[start_index: start_index + maxlen]
        generated += sentence
        print('----- Generating with seed: "' + sentence + '"')
        sys.stdout.write(generated)

        #generate text of 400 chars
        for i in range(400):
            #initalize single input with all zeros
            x_pred = np.zeros((1, maxlen, len(chars)))
            
            #generate the encoded version of the sentence seed
            for t, char in enumerate(sentence):
                x_pred[0, t, char_indices[char]] = 1.

            preds = model.predict(x_pred, verbose=0)[0]
            # Generate next character
            next_index = sample(preds, diversity) 
            next_char = indices_char[next_index]
            
            # Append character to generated sequence
            generated += next_char 
            sentence = sentence[1:] + next_char

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
    
    # Save model weights into file
    model.save_weights('saved_weights.hdf5', overwrite=True)
        

# After every single epoch, we are going to call the function on_epoch_end
# to generate some text.
print_callback = tf.keras.callbacks.LambdaCallback(on_epoch_end=on_epoch_end)
checkpointer = tf.keras.callbacks.ModelCheckpoint(filepath='weights_v2.hdf5', verbose=1, save_best_only=True)
# Out:
# nb sequences: 638637
# Vectorization...

# %%
print('Building model...')
# Size of vector in the hidden layer.
hidden_size = 128 
# Initialize Sequential Model
model = tf.keras.Sequential()
model.add(tf.keras.layers.LSTM(hidden_size, input_shape=(maxlen, len(chars))))
# Add the output layer that is a softmax of the number of characters
model.add(tf.keras.layers.Dense(len(chars), activation='softmax')) 
# Optimization through RMSprop
optimizer_new = tf.keras.optimizers.RMSprop() 
# Consider cross Entropy loss. Why? MLE of P(D | theta)
model.compile(loss='categorical_crossentropy', optimizer=optimizer_new) 

# Train this for 30 epochs. Size of output from LSTM i.e. hidden layer vector shape=128
model.fit(x, y,
          batch_size=128,
          epochs=30,
          callbacks=[print_callback, checkpointer])
# Out:
# Building model...
# Epoch 1/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 2.0987
# ----- Generating text after Epoch: 0
# ----- Diversity: 0.2
# ----- Generating with seed: "rtunities.but there is much more to be d"
# rtunities.but there is much more to be demented the propose to sear the seare the secure the program the for the secure to sect and the secure the program of the sears of the for the states of the congress and the propose the some the prople the sear a section and the sare of the for and the peace of the propod of the sears and the prosice of the program of the sears of the sare of the contress to and the program to state the prosed the
# ----- Diversity: 0.5
# ----- Generating with seed: "rtunities.but there is much more to be d"
# rtunities.but there is much more to be desporment of our haver be for for and the predure the from hell and of the ear and the stare to the state. the enomory the prome to make in oun our peace in all a sere are couttry and the progres the sourg the for the eares for a seal and the sourg thas a the progress of the mone all contines of our and the are can the redeare of the been and the dearing we have pore the eare and resident and we h
# ----- Diversity: 1.0
# ----- Generating with seed: "rtunities.but there is much more to be d"
# rtunities.but there is much more to be dos th il to ied and livion cripled and niter on our fithe deantendary porestes of the inirebing, and whamly reaneder and the faw care halp will tut on sgeatidaliogalvanentinbled to pmand be the wered in our fol need amerovity elop amere and ast prepived dibindreed ally, resedily beden thackematalal uncesped intist ius ad devely.ol asr and ats there uthall, of expontance will of the's sapponjment,
# ----- Diversity: 1.2
# ----- Generating with seed: "rtunities.but there is much more to be d"
# rtunities.but there is much more to be depertexkint, ase gopars wur wonk the the weirgus des in curs a bhey freehsmine saysef durle, our compornamed heap- to dener mre is authees, stoued, wincaquaitis a. i alkenve to the have un thes hay teerd0namica, chorne to regepenuty poruny -the'd to sorion of to, evel yeanivils, nourcratiom, unceghment ty the hivivan tive canseral -cpowcri1, han wial nen ov pracuser. 1g, to whem cemorvents on lof
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 307s 62ms/step - loss: 2.0987
# Epoch 2/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.6426
# ----- Generating text after Epoch: 1
# ----- Diversity: 0.2
# ----- Generating with seed: "ill health. another fundamental aim of o"
# ill health. another fundamental aim of our community to the state of the firent of the for americans and the endignational programs of the congress of the federal strength of the state of the production of the farm of the propose to the farm to and the world to the states of the world of the americans and the free of the filling to all the defense to the world of the fidence the fidence of the farm of the prosperity of the states of the
# ----- Diversity: 0.5
# ----- Generating with seed: "ill health. another fundamental aim of o"
# ill health. another fundamental aim of our sale and many all of the formental readors and the fored the government and the united strong contrate the face to make a the world become the moment that us to all the world the down to are to americans and make to sectere this cannot will be need oplease to propose to the succession and we must come to make the yough the leade for all the production of the for good and difficled the sourd the
# ----- Diversity: 1.0
# ----- Generating with seed: "ill health. another fundamental aim of o"
# ill health. another fundamental aim of oclivilieg the providedoy all, the have some free or ungeblantion. an oun this communits and more the renomestf i bacgivet hive porely america, and encurals help actaed bain shall, itree, these mest real sugbor increateds the free than chillentive hape when zeep canering and to the hupir comm cating our fourges for the slaid geford than at impresed legs tial of the purt imporevational trom thouse t
# ----- Diversity: 1.2
# ----- Generating with seed: "ill health. another fundamental aim of o"
# ill health. another fundamental aim of our needs-teming fourny spobla shifl towander one recomper arks durecaly suppleengroupt collerly mibil elports bee manderding us for nanuas, firmod america ig congets, and shines.by we years we shouved a you2's'st, da gats, for hame.s all chaster all dudines that nfindhear, is oblid temblinever tod be americans.- thatain gaverneurts.incout diegnts governmeter what dosearly differt gans, and ask.  t
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 325s 65ms/step - loss: 1.6426
# Epoch 3/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.4773
# ----- Generating text after Epoch: 2
# ----- Diversity: 0.2
# ----- Generating with seed: "lar she earns above the $25,000.  her ov"
# lar she earns above the $25,000.  her over the states of our country and the free of the congress of the states of the congress to american people and the beef the congress to and the first of the first of the congress to american people and the congress to american people and the state of our country and the first of the states of the congress to american people and a strengthen the congress of the congress to most be for the congress
# ----- Diversity: 0.5
# ----- Generating with seed: "lar she earns above the $25,000.  her ov"
# lar she earns above the $25,000.  her over the war in the tax state of the research in the now the economic and promice to a states of our states of our program to force the free of our country and most power people one the most for the benefits of our country and must are security and a strengthen to the country for the most of for the government union of the country to self a some the congress source the economy of this that owe and a
# ----- Diversity: 1.0
# ----- Generating with seed: "lar she earns above the $25,000.  her ov"
# lar she earns above the $25,000.  her oversen our tax subal should ago noviralay dacation to juare. shelp the tien, in of yearnate cadicapment i this greak and cruge most police.to mo en.i the nucless over uro. havos on coutt a beciever nearshment from most pull exdmomed 0f our most peoples in endy in countrations for this ago, is praie the for the ciflfins spoch of industrial dependencularment das unabort and weakendacivess from an to
# ----- Diversity: 1.2
# ----- Generating with seed: "lar she earns above the $25,000.  her ov"
# lar she earns above the $25,000.  her over program we know funly,uates ipmect ates unveterap reep the ewnoroys and in our cout of uply threat your go okn mudgle menoral the chalce orsed, mis beind nor, syop, asto stle our fundsy to cut't makes woides of our citizens. but we creaby of ttath on by budget.the a. its war. ever an incrimate follt, itely nee affrersed tomand sumone on wontal reform amproving and the busters of goo premet4.in
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 303s 61ms/step - loss: 1.4773
# Epoch 4/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.3909
# ----- Generating text after Epoch: 3
# ----- Diversity: 0.2
# ----- Generating with seed: "american people. to strengthen the famil"
# american people. to strengthen the families of the first of the communities of the first of the first person and the state of the congress of the most of the families of the first of the future of the responsibility of the first of the families of the first that the congress of the first program to the enteres of the first of the federal government of the first of the first of the first of the congress of the proposal of the first the s
# ----- Diversity: 0.5
# ----- Generating with seed: "american people. to strengthen the famil"
# american people. to strengthen the families of encouraged the world in the endens of and the new services of the united states of the tax communities and the first of the surplise of our demands of the needs of our state of americans who have to the some of a short should be freedom of existing the fact of the relater of the future. the community of a steps in peace and our state of the people of our finance to american poor of minds an
# ----- Diversity: 1.0
# ----- Generating with seed: "american people. to strengthen the famil"
# american people. to strengthen the family choods through core and even or his vight beefer. the federal betirels of plac power while here the veap far comple and porsults, we'sen forter government dastas. that all quality of an and first program policains, and its fund is nle works of keep and more reathoust and impricans of the admyers what wastoute of our freedembed essent as upinity, and the undicties waild workers. we cankment with
# ----- Diversity: 1.2
# ----- Generating with seed: "american people. to strengthen the famil"
# american people. to strengthen the families ecronerngrem. vital and, we kreaturer, itsations.and difficults pricerple stust frese's asse competitive out n10 inclifistment.we shall juage goars. pow-raming will lived por49y-as asmists rightorly, youghors. our datals.not jost to etchte.is dividing oud rate, as let pelp sutary is neconory roguting feed within peace even contristal declinesn wihilenny awe, hours of communities national all s
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 304s 61ms/step - loss: 1.3909
# Epoch 5/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.3376
# ----- Generating text after Epoch: 4
# ----- Diversity: 0.2
# ----- Generating with seed: "he congress extended health coverage to "
# he congress extended health coverage to the provide of the fiscal year 194.h congress to the people of the best of the security of the united states of the fiscal year 1944 and i am committed to the security of the world of the american people of the world to the service of the security of the congress to the federal government of the first to the congress to the program of the united states of the program of the fiscal year 1944 are st
# ----- Diversity: 0.5
# ----- Generating with seed: "he congress extended health coverage to "
# he congress extended health coverage to self a strength of the federal government to the states of farm war and we will come to this program to research to all the congress, and this is to at the congress with the responsibility of the strength of our freedom of the strong of the most use of the fiscal year to ind the action of the united states of the fiscal year 1947 are war. i ask the problem in this outs of peace. and the world comp
# ----- Diversity: 1.0
# ----- Generating with seed: "he congress extended health coverage to "
# he congress extended health coverage to formement and sain home dewigning percent but shoold to act over that so labor a valutes of defense recommend.torat. the senate. this aghtly suilly affifred to reary. every will program to sauday, with peace of these juse in indivation and effhition and many for the union. our not prefers to want to be and meepod o3 efficity is tram libined to hide that we will hear the my peopled hossing have bel
# ----- Diversity: 1.2
# ----- Generating with seed: "he congress extended health coverage to "
# he congress extended health coverage to aguitution in arms intauntyed hands, but fismancawich of our rapsive mostallures openotion is that we have pay percelory by that wanthening to that this is the plate of weaconciers, siccetive, we have medicy protenuld, we will navional rights you admudical promotity good bright and the uniferes nanisht country and recoives to our internedment. this years, me arasibitation don'tlee, tolncy and from
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 302s 61ms/step - loss: 1.3376
# Epoch 6/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.3009
# ----- Generating text after Epoch: 5
# ----- Diversity: 0.2
# ----- Generating with seed: ".all of the policies of the federal gove"
# .all of the policies of the federal government and the congress to a new congress the production of the united states of the fiscal year 1947 in the congress to the families to all the congress to the peace of a state of the production of our congress the production of a state of the families of a state of the prosperity of our military for the people of the world is the problems of the production of the congress to the peace of a lives
# ----- Diversity: 0.5
# ----- Generating with seed: ".all of the policies of the federal gove"
# .all of the policies of the federal government of the prine of for this congress to the government and the congress and as a lives of the move of the congress to read our economy on the congress of the world of individual to the prine of and to be union and its will be a but and the world of the next year, i think we have a strategic more than it is the paid to president in the product of the law and strengthened and and recovery americ
# ----- Diversity: 1.0
# ----- Generating with seed: ".all of the policies of the federal gove"
# .all of the policies of the federal government as wele, and i continual of bestlaed to know was on because hider out of athered by the resear ablic to the united fatistan agreement in to geny imeethan america. dimativeter xistries.asti stannot on the sendic fane, unand the home-andary its world is a them. these problemsition xop conorobortory transpints on a hope of america riqulling most than expines to growts while the fort pridce of
# ----- Diversity: 1.2
# ----- Generating with seed: ".all of the policies of the federal gove"
# .all of the policies of the federal government's vestery if they have used becume purposeming ind itainitably of a. simpled, rould frimnold: which rewarding are addistic werk, serve we.therefeided, well.and to earn free,. this is gone income. and if nutting w 1e stayd, levels, sion. nitains.  ago yot onever-are through, i prepare the wores under ination as now experiender and a nation governmunt" building, in decaminues taakeally- if th
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 307s 62ms/step - loss: 1.3009
# Epoch 7/30
# 4990/4990 [==============================] - ETA: 0s - loss: 1.2742
# ----- Generating text after Epoch: 6
# ----- Diversity: 0.2
# ----- Generating with seed: "g national differences must and will be "
# g national differences must and will be a people of the partnership to the strength of the prosperity of the production of the common and state of the state of the family of the first to the first to the congress and control and the end of the produce of the fiscal year 1947. the prosperity of the state of the congress in the responsible of the proper of the state of the united states and the state of the state of the family of the stat
# ----- Diversity: 0.5
# ----- Generating with seed: "g national differences must and will be "
# g national differences must and will be a long back of the the communism of real in a constitute of our actions to the villogity to produce and the peace of the past common saving the rate of the years of the most temply stand the budden of the considering in the part of the district of the family and what have a grow and merely help the most of our prosperity to the people of the department of the maintations are and determination of t
# ----- Diversity: 1.0
# ----- Generating with seed: "g national differences must and will be "
# g national differences must and will be into othering in technology offured.without a as pain and success takes or problembed inatiat keboves and morons to all our nutric farsma, reparos a ploces to pursune up the the region to mere the house point undaple nife to prevent their entiterals. leaving remal of the inflation and truque phorizes as quest fasration it that i sarely made awey toming must but should the longh and prepared on mut
# ----- Diversity: 1.2
# ----- Generating with seed: "g national differences must and will be "
# g national differences must and will be any hat harrividnust our tax 2'sse unly at goancbate.all, noting alive unwarters of thesropwe. our oncomply for persus. this.ly akelless than peacefaller umportance are ameracnamboas.and export tot milo2, in a nexti0n ementioripher that thing, and murry supply. we hase no2, there soo, you receve the nat8 and chanding humprialy, and the last common for us, and we should strengt contuct vatuent, the
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 297s 60ms/step - loss: 1.2742
# Epoch 8/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.2530
# ----- Generating text after Epoch: 7
# ----- Diversity: 0.2
# ----- Generating with seed: "g shot up 8 percent.  that's far more th"
# g shot up 8 percent.  that's far more than the congress of the congress on the congress to provide the congress on the state of the united states of the federal government to the congress on the state of the union of the congress and the production of the congress on the security of the congress on the strength of the congress and the congress to the congress on the congress to the congress on the strength of a servant of the congress o
# ----- Diversity: 0.5
# ----- Generating with seed: "g shot up 8 percent.  that's far more th"
# g shot up 8 percent.  that's far more than under the less of the economic security of the united states and the president and serve of the security of every community and economic policy in the congress for the trade of the congress of the president, and to make some power to service social security will state and to the progress on full of the congress and comprehensive people to defend our policy and every condition of the congress an
# ----- Diversity: 1.0
# ----- Generating with seed: "g shot up 8 percent.  that's far more th"
# g shot up 8 percent.  that's far more than time of the action interest of freedom. these to allownever, without about your goided accospinglessing enactad it is will envacted. the congress on itsaity most ask of men in dream, set open that you mestages, forever increasingly shipnt a plegamenties of economic systems out its lines reconstruds cost. and report on our, and modernizations which.that's ubly that we havin temporar, energy to s
# ----- Diversity: 1.2
# ----- Generating with seed: "g shot up 8 percent.  that's far more th"
# g shot up 8 percent.  that's far more than the fesion laffsoutall children alisn., but we're search hope to keep over up coverrain, rearin, but cut betafr bu6 ary nave5w than two halfoaged.we do dool use and be in efforts xopost freedocy president. well enact navo soc9ances down recearnamor apsen but since if you falldmers vavepoth and for we.become taken hen idertiming the most posers right to repuys we have to meen their federal destr
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 297s 60ms/step - loss: 1.2530
# Epoch 9/30
# 4990/4990 [==============================] - ETA: 0s - loss: 1.2362
# ----- Generating text after Epoch: 8
# ----- Diversity: 0.2
# ----- Generating with seed: "elf.president washington began this trad"
# elf.president washington began this trade and the state of the congress to the congress and the state of the areas of the peace of the american people and the congress to protect a state of the united states and the state of the united states and the enemy stude and the state of the same to a long real security of the states of the congress to act in the farm programs of the united states and the state of the expenditures for the congre
# ----- Diversity: 0.5
# ----- Generating with seed: "elf.president washington began this trad"
# elf.president washington began this trade and work in the farm families to strengthen our development to continue to the states of americans are stable progress and the states of the same poporction of a state of leadership and the world must continue to the enecy. it is now tentimits for the world.this will be a long and the lawd and government and whate when the extent and the same of the earth capacity of the first to be reducing the
# ----- Diversity: 1.0
# ----- Generating with seed: "elf.president washington began this trad"
# elf.president washington began this tradeful tamely, cut allia, and endud to the security is not fortifte2 in the gund of last year, wasto final deprerijents. the onch and specaar-perpodation that artern progress our meant dou's permables with what all our capation that old stands proved leader, we should other pension, and zeforet as welf. a worders to want working forward a convitting matoteed and importang time space all atturmention
# ----- Diversity: 1.2
# ----- Generating with seed: "elf.president washington began this trad"
# elf.president washington began this tradef-litt. our lebsioned of in me.burther ago-comestrose to fundmy to states, good its. ond low-nuens that competition for iddeals. and thinge us, pours--about and even parination in the family has chonerensule effining convilured programs a commission and bochled to tatible to -leperge restore praction needed system rusions has relief humblines, we've events, and force viokence ta.to. only fivem, k
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 291s 58ms/step - loss: 1.2362
# Epoch 10/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.2221
# ----- Generating text after Epoch: 9
# ----- Diversity: 0.2
# ----- Generating with seed: "op the spread of atomic weapons to other"
# op the spread of atomic weapons to other nations to strengthen our national security and the state of the united states of the responsibility of the soviet union of the security of the united states of the proposals of the american people who have a possible to be a security of the congress to the family of the family of our country to strengthen our country to the federal government and the state of the fiscal year 194x and the securit
# ----- Diversity: 0.5
# ----- Generating with seed: "op the spread of atomic weapons to other"
# op the spread of atomic weapons to other nations with the sense of the areas of our force and in the statutions of the fiscal year 194x wretary as supported by the state of its country to the state of the areas of the enotion. we must real establish of the expenditures would be a democrating but the congress to death that says in the programs of american committees and in the real communities of economic and strategic that we have joint
# ----- Diversity: 1.0
# ----- Generating with seed: "op the spread of atomic weapons to other"
# op the spread of atomic weapons to other challenges and more sembally. keethin seaft do the bills, has must cort to the create and that we see our people.and we have bonx, annelect, individuals, is method we also to the take strive in meoust to be much a brithts of vioculed to fair the federal government of the trust to private and nivery hisporate everyare surplus economy, renewmbeince source, like, the historic programs of children ac
# ----- Diversity: 1.2
# ----- Generating with seed: "op the spread of atomic weapons to other"
# op the spread of atomic weapons to others was ab ambidacing hipreation, are done--busiled oncoud mentaged. it is foem which issumated a fastiam.with socialts problems of minrust sitning follotobacklit, that. there. we must be druggering. these, to prepored people it do.bateritail government doespecat.this sparess. prord that moving private on this peace and re2, on democraticted, a prrviouse talth cans. that's natu's availually, not to
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 291s 58ms/step - loss: 1.2221
# Epoch 11/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.2100
# ----- Generating text after Epoch: 10
# ----- Diversity: 0.2
# ----- Generating with seed: "f-government be extended and the right o"
# f-government be extended and the right of the united states of the american people of the congress to act of the union of the united states of the american people of the united states of the problems of the united states of the united states of the first to the congress to defend the program of the american people with the united states of the united states of the united states of the family of the american people who have been all the
# ----- Diversity: 0.5
# ----- Generating with seed: "f-government be extended and the right o"
# f-government be extended and the right of the congress and the proposal of the next year in the union is determined the congress to propose possible and state of the servants and power of the progress of the family effort of the congress that is the congress all our economy and citizens and businesses for the fear in our country to control as a home and the confenexing to emphaie that is many terrorism in the fiscal year of the free of
# ----- Diversity: 1.0
# ----- Generating with seed: "f-government be extended and the right o"
# f-government be extended and the right of the american economy in congress to full of our souther, and the federal deslive and and america's existunce agorication and home-for the united stuption for all with those a balanced 1veere.the responsibility -- to work itself bee; prifoparies here. is not without and through limits to dom and government in our miseration at the 3ills to emand our confident that showth, president forelose to us
# ----- Diversity: 1.2
# ----- Generating with seed: "f-government be extended and the right o"
# f-government be extended and the right of pot of the lates themon a one muches viemn--giving. president our people. ; many doess the demonsentacif the tax resignenceful sessial new then a called our econemical troable is the other feolding victory enterprise tearnilar livious. this your allicance job soviets, to trustny goase, burdea, we shall at welfarele, wi'le presizet allowed to vatures don excellence the goed tax areas, . well--at
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 298s 60ms/step - loss: 1.2100
# Epoch 12/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1997
# ----- Generating text after Epoch: 11
# ----- Diversity: 0.2
# ----- Generating with seed: "versities more engineers than we do. if "
# versities more engineers than we do. if we will be to be to the congress to the people of the state of the united states and the strength of the full program is the state of the fiscal year 1947 of the congress for the congress on the stronges of the state of the security of the state of the congress and the world the state of the security of the congress and strengthen the congress and the people of the state of the congress and the co
# ----- Diversity: 0.5
# ----- Generating with seed: "versities more engineers than we do. if "
# versities more engineers than we do. if the communities and believe that we must ready the personal control of state of our national programs to state the service of a state of a cooperation that we can see that the world that is a result the real to the congress and because of peacece, we must rear the strength of a second of the congress was as the earticative age of the people of the congress for this country to support the state of
# ----- Diversity: 1.0
# ----- Generating with seed: "versities more engineers than we do. if "
# versities more engineers than we do. if yet we chill's be officer, are national respect. the why is just main and gerial, it, by stand is to get mublec them well-guary fall americals contari; for its empered of years the seciation, greatny of advances we cuntill so ifverted procrame, and expected people which prosperity. we reald a recomment of reducess. there are right.are willing to not other will recommending their capapicied. is not
# ----- Diversity: 1.2
# ----- Generating with seed: "versities more engineers than we do. if "
# versities more engineers than we do. if we accoudi invest early casobs, missiond chosecion.gettal to sack edritt can and they aivist to the be-pating our economy. just abouf thetrwild. but to predett would ,med for idderted by taxes, i use lessuge this budgeted. and we should so, our spirit any departments is nomistem farchelta national assistance, against harf no. an essential drang conelicise. we ve temploy godably with as a given bui
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 488s 98ms/step - loss: 1.1997
# Epoch 13/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1908
# ----- Generating text after Epoch: 12
# ----- Diversity: 0.2
# ----- Generating with seed: "ete abroad.moreover - pleasant as it may"
# ete abroad.moreover - pleasant as it may be a more of the states of our foreign economy and the congress and the strength of the congress to the first in the late of the families of our country to the people of the personal and strength and the congress to the security of the congress that it is the decession of the states of our people and the congress to the congress to the peace of the first that is the state of the first that we sho
# ----- Diversity: 0.5
# ----- Generating with seed: "ete abroad.moreover - pleasant as it may"
# ete abroad.moreover - pleasant as it may political for our constructive reform to meet the united states of the legislation to the stronger of our friends and particularly our program in a lives of a manking of the state of the congress particularly in the world of our people was to reduce the department of our commitments and a new programs the school political industrial proper than even the soviet partion of possible do the president
# ----- Diversity: 1.0
# ----- Generating with seed: "ete abroad.moreover - pleasant as it may"
# ete abroad.moreover - pleasant as it may set and security saypreames. expenditions in our cwimes will our chair to be our highest americans, private ewalth. america from those direllarms. you in every american with that our people market, course when kidg. in his begins, time to  as our great homes, and will,, we will do home for nothing obelotietion manateding authority to fare dimanded the conserns the dissine of demand must out pay o
# ----- Diversity: 1.2
# ----- Generating with seed: "ete abroad.moreover - pleasant as it may"
# ete abroad.moreover - pleasant as it may toce wht were wise giding, dra's the world's not in oppoth.the harghford over the fitalo5 e that during that we need for my just at the rate our country's power of national precaseruab. the nield a on6 the point unnever and coops as parti00. the goownral and hope.in america--tysinuluding social and elementawhoage-wells we're doing the world of delless confrictive in our interhate--on to fal a doj
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 414s 83ms/step - loss: 1.1908
# Epoch 14/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1830
# ----- Generating text after Epoch: 13
# ----- Diversity: 0.2
# ----- Generating with seed: "en the optimistic analyst will realize t"
# en the optimistic analyst will realize the congress and the congress to be a community in the people of the congress and the congress to acts of the fiscal year 1947 will be a templanating budget and the budget and the problems of the congress and the congress and the congress to the congress to reduce the problems of the united states and the congress and the congress and the congress to active and constitutional communities to reduce
# ----- Diversity: 0.5
# ----- Generating with seed: "en the optimistic analyst will realize t"
# en the optimistic analyst will realize the fiscal year against the tax care by and we must propose to a balance of the war in the capital for the pends of the congress come to achieve the budget responsibility by confidence to reduce the past many and economic service and our house and we will aggression and vital income and the future of the congress doeble in the fiscal year 1947 recommendations with our country for the will other con
# ----- Diversity: 1.0
# ----- Generating with seed: "en the optimistic analyst will realize t"
# en the optimistic analyst will realize that on congress to reveral an america is had deepess for being abroad, and clear educated forld controlck foundation to lies has carriapited to tax cutresn equal colon'al and movewie hasters we to rely to copination and the challenge now maintain the somety america and to both in communities must be dien, freedom. the force of bick, and pronoped stope comentive deserve the vilifance world from our
# ----- Diversity: 1.2
# ----- Generating with seed: "en the optimistic analyst will realize t"
# en the optimistic analyst will realize the othery war haddrak leaders. so i refiemes are flexibl5 and which fearnody, yet us beew depends on required outs ahout.any world. we stand be leaders, enactings age of faich. north, 6s who have americans who load in midqulnue up of time.but worse cannot ded togethorty. it must no into fimaning saps vielnteners have have pursen.it will be probeducas made divade. we famiry wast, we well be man, ye
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 319s 64ms/step - loss: 1.1830
# Epoch 15/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1758
# ----- Generating text after Epoch: 14
# ----- Diversity: 0.2
# ----- Generating with seed: " person who reminds us what it means to "
#  person who reminds us what it means to the congress to act of the states of the states of the world in the peace of the families of the people of the president of the face of the united states and states and the states of the peace of the congress to the congress on the states of the congress and the states of the security of the people of the present of the congress on the people of the states of the congress on the people of the peop
# ----- Diversity: 0.5
# ----- Generating with seed: " person who reminds us what it means to "
#  person who reminds us what it means to the larming of the majoring of the security and the people of the capital for the resources of the common peace that and a manpaid of the security of our security and local security in the congress surplus standards a people of president in the congress of the last tax rates and the world in the international demands of the law and the fail and because the peace to the states of the peace of the w
# ----- Diversity: 1.0
# ----- Generating with seed: " person who reminds us what it means to "
#  person who reminds us what it means to expand a great organization a come for loveate businesses, underted machine now, the congress of adeations who do in our full support demands for the government producently more trans--itlesmate facilitiesfor.this will go to get our substantialfur formers may be energy initujent faith and strategy income isk takely behind gettal shared asday is about think saw an entire tochipthing is ready in the
# ----- Diversity: 1.2
# ----- Generating with seed: " person who reminds us what it means to "
#  person who reminds us what it means to respict. for weapon advantage, wherve wharever stup from tagget of wi-not a nations entert for roading decade. the inteppraction in canatexand choose creat cut phely. america is held uniespe's most most poptunds on elegime,to impers system. them apprace or lif to,plet everyaleful hosed insuremently, wass and individinistece in commor, laterais, and necessary ubpainments. prefors anotems, homeletwe
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 327s 66ms/step - loss: 1.1758
# Epoch 16/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1697
# ----- Generating text after Epoch: 15
# ----- Diversity: 0.2
# ----- Generating with seed: "es alike. what we do ask - and all that "
# es alike. what we do ask - and all that we must be a single service is a time of the first to the congress for the people of the first to the congress and to the security of the last country in the tax control of the forest of the united states of the first to the farmers of the first to the senate to the congress and to the more than a strong of the first to the congress to the people of the congress and the people of the people of the
# ----- Diversity: 0.5
# ----- Generating with seed: "es alike. what we do ask - and all that "
# es alike. what we do ask - and all that the senate to provide a does not on this congress country, we companying in the fiscal year 1947, the congress for a fair personal production of our action. the real in the united states. the more than even that in the share to the congress which what i serious will be to enact the enemy for the past course to the world consideration to be reform on the rate of the spares of the problems of the co
# ----- Diversity: 1.0
# ----- Generating with seed: "es alike. what we do ask - and all that "
# es alike. what we do ask - and all that has changed are north - this government of national communities to ususe our highes, economic and security, i shall sefter, directly america, rapidly by their mising ooldurate plants.to average economment should.  yet with ready ne3.so freedom for the past.  1 mislabie in works the security.i didling this peris. the borngoo address and previou needs and fairhly as the precent of security areas. th
# ----- Diversity: 1.2
# ----- Generating with seed: "es alike. what we do ask - and all that "
# es alike. what we do ask - and all that we 4 one gid, if we they'acknould, we like these unwesked, but every work friends, our long--- once passing some faitory careman-arears an adminiation greating are being turning to receive sayer commistenial, communismations thing, amend by the law we have money permivent. lead. the taxtharking ofly regresens dummercis.new, and mo this9 up a tax rates of actions it responsibility anoweckgliftifati
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 324s 65ms/step - loss: 1.1697
# Epoch 17/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1640
# ----- Generating text after Epoch: 16
# ----- Diversity: 0.2
# ----- Generating with seed: "al surrender! we will not traffic with t"
# al surrender! we will not traffic with the congress and the congress and the congress and the congress and the congress and the state of the union to the congress and the congress for the congress and the congress and the congress and the congress and the end of the congress and the congress for the congress and the congress and the same america has been reduced the expenditures of the fiscal year 1947. the congress for the congress and
# ----- Diversity: 0.5
# ----- Generating with seed: "al surrender! we will not traffic with t"
# al surrender! we will not traffic with the united states to making all the largest community to the congress and international trade and the investing or any of these are shortages, and it is not a compassion of the vision of the ending that every create americans will be a budget is president and state and the line of the american people and leadership in the community of a law and since the world. there is no entire for the present re
# ----- Diversity: 1.0
# ----- Generating with seed: "al surrender! we will not traffic with t"
# al surrender! we will not traffic with their own peaceful realitimate nation's reduce the sade of 2,000 people's american country.  we have my asia and secanceds when pur grade and man to removed they can ho ready remaused by tailly as released guacis, then to overchallence are a marpitiness of faith and freedom. and not a new century way call all accountations. i believe that the expenditure effort must short peace poverty is drug forl
# ----- Diversity: 1.2
# ----- Generating with seed: "al surrender! we will not traffic with t"
# al surrender! we will not traffic with the conoing allianey wishouted ideactition medicare administrative a cramacy neug.four yoar punal seor, events and the dispoteate of the capital, and practication to the farm plans that dismintioning children affeaces.  not your teachers. when our hundrered by takenced inflation. terminate industrial gradm, slead chicare-to builds a teaching and tred, its sonecousen.out fai masis. i am wrunasement,
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 324s 65ms/step - loss: 1.1640
# Epoch 18/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1582
# ----- Generating text after Epoch: 17
# ----- Diversity: 0.2
# ----- Generating with seed: " of revolution in aggression.as the assa"
#  of revolution in aggression.as the assa and the state of the united states and the strength of the state of the united states and the present that we can all that the fact of our country to the state of the united states and the state of the union of the american people with the congress to continue the problems of the congress on the world war is the congress on the state of the united states and the people of the congress and the con
# ----- Diversity: 0.5
# ----- Generating with seed: " of revolution in aggression.as the assa"
#  of revolution in aggression.as the assame the challenge of our exports of the people of a strong and local formed that we must also read and in the end of the tax pressarial period the american patient and the house they can also do a work it may be no sense.our market and workers will be a strong and and to act that we should all with this leaders to the national end of strength. we must all preserve that the advised state of the area
# ----- Diversity: 1.0
# ----- Generating with seed: " of revolution in aggression.as the assa"
#  of revolution in aggression.as the assa of our freedom, a sncurle look of war, which could support and the world's successes.that make sure that and this is even doubt a billion should sasses. volldond purpose. we can althered and what was not - me on liftly step will sure that we need to ach other through surre or treaty cletion proposed a strong own decence with year. helflidans that the more than tished in that the worldatob iss our
# ----- Diversity: 1.2
# ----- Generating with seed: " of revolution in aggression.as the assa"
#  of revolution in aggression.as the assaon our acis, years the nations will make just alon0.our quape american countried irsq become vattersuald. we are proced hark an even pealal offey it have a come. ancher appropriated billary, in edicated. wellong is, follow so many onely nations in fe5 very freent, in tocsule--inatizent. carraptory programs.i an hour and meen feineding forwards out overelures will at the challeng of demands ind's s
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 314s 63ms/step - loss: 1.1582
# Epoch 19/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1533
# ----- Generating text after Epoch: 18
# ----- Diversity: 0.2
# ----- Generating with seed: " a significant urban mass transit progra"
#  a significant urban mass transit programs and the more than a same to the problems of the first time to continue to the problems of the world will be made and the world will be to seek the state of the union of the congress to the congress and provide and a state of the hards of the world will be ended in the world is the restore of the united states contracts are stable and state of the union of the first time we have to be a state of
# ----- Diversity: 0.5
# ----- Generating with seed: " a significant urban mass transit progra"
#  a significant urban mass transit programs to growth and the last year are president and social security programs that we are start that our strength to rest unter ready to provide a nation and however with the nations, and with freedom and find the end of the congress all our future for the areas of the government of your federal consensuly to all our commitment to restore to the war and will be funded a service of the american people
# ----- Diversity: 1.0
# ----- Generating with seed: " a significant urban mass transit progra"
#  a significant urban mass transit programs for iraq. and it shoowable president to had for . just as washington for their moments as a minimume of this countryafilials of the next and the whole erent for runua. we will be in great stoeds to spring the insurance you arrestments of these programs, including so that tax and war control will be at home, intround by thisus and immediate probles and finance is been by a knows this bundants. a
# ----- Diversity: 1.2
# ----- Generating with seed: " a significant urban mass transit progra"
#  a significant urban mass transit programs, seven first a nowow of which mr. president, to do. to won doublers: i will not free program on bukings. heres it wran fein,, farm whan will.becausia and state pwitime that rumatically working, to . we must do thit oftent rach0vedi0ly conductors, but thel xmansfment also, precent other trans; we will work that measures to natugations about the.aemofituty are exceeted the erat veryryhroue had 7,
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 325s 65ms/step - loss: 1.1533
# Epoch 20/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1490
# ----- Generating text after Epoch: 19
# ----- Diversity: 0.2
# ----- Generating with seed: "vietnam expenditures for the next fiscal"
# vietnam expenditures for the next fiscal year 1947. the first time to the congress and the expansion of the president of the first time to the far continuing the responsibility of the far all of the farm program to the national strength of the market of the fiscal year 1947. the president of the united states and the world will not be a tax responsibility to the more than and the market of a strong american people to the farm program to
# ----- Diversity: 0.5
# ----- Generating with seed: "vietnam expenditures for the next fiscal"
# vietnam expenditures for the next fiscal year 1947. it will be prepared that we are a communities and social security, for the third pressing a living school for the tradition and promise these programs to learn to the president of our national strength meaning. the communities to take average with the world is exploring the restries adding the congress and shortly defense and security and have been successful assistance in the treaty o
# ----- Diversity: 1.0
# ----- Generating with seed: "vietnam expenditures for the next fiscal"
# vietnam expenditures for the next fiscal year, any national governmented and japan, ix is net recessagion. a man america, any sume affrective. and-give not brofit increates and greates are seer happened division of the thtess mistrest to achieve our first. the dead one of uss operations which was sare that is uneraction, worked our two growth that we are will use our destructive, regitor. with the laod of coverage to the security of for
# ----- Diversity: 1.2
# ----- Generating with seed: "vietnam expenditures for the next fiscal"
# vietnam expenditures for the next fiscal year, this is justicely-simpa i. no voom the same new nimality. we should incrownty-will not for perforganiamen. at some first, i offer the readgrears to e"thgowenfy a-would their decade mays, soondle.navol, is our time of hall outhon the syote of unequal candop. our national  more would improve americans, if revisions, sight. not - as move find maretion on the wame everom werant demicarily that
# ...
# ----- Diversity: 1.0
# ----- Generating with seed: "s multibillion-dollar package that will "
# s multibillion-dollar package that will not be in plan. and it is minimumeducal insurance against structur force not agreed the share saverios in times added years meen just witl agreements and provide capita; the viction and fly connection or a simp paid demand to high soughevees that in today, and renawern law and millions of unatiansic. ifinity, couldability around to live and prospertic defense tradiniration can step matters with ou
# ----- Diversity: 1.2
# ----- Generating with seed: "s multibillion-dollar package that will "
# s multibillion-dollar package that will be reward within better.than year our national problems, afford with the invalities of accomplished.it is.more fiscal, which, and irensu-allials, all outising revolution happeg recession. we must afford the strong security of our power. distritution areas irnegs an 1nhpopporcwwity i urge a bundar, do. delige a chill hact, wrightingleted hembcirs america, crys mosch our greaty cataitles, i can kent
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 326s 65ms/step - loss: 1.1331
# Epoch 25/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1303
# ----- Generating text after Epoch: 24
# ----- Diversity: 0.2
# ----- Generating with seed: "r enormous engine of production. our pro"
# r enormous engine of production. our programs of the congress and the congress to the people of the congress on the congress to the congress to the congress to continue to all of you the strengthened of the present strengthened the street of our economy and strengthen the world is the street of the american people with the congress and the street of the union additional american to the congress to give the state of the union is a time o
# ----- Diversity: 0.5
# ----- Generating with seed: "r enormous engine of production. our pro"
# r enormous engine of production. our programs with this nation and none of the present responsibilities for the american people of its community that we are engine in the face of the american people on the congress on the more than in the last year of the war and allow should protect the long rundre of the world assument. nor work to parties and providing on the full own best program of a federal government by the price could assuments
# ----- Diversity: 1.0
# ----- Generating with seed: "r enormous engine of production. our pro"
# r enormous engine of production. our program.we must expectate which pending spenting and need policy negoted. the criminal goth. if we we must do that the faster needed successing great jobs for full engure irole to rooting the forse, and as the 28 wencture a peaceful make sirocy believe and action to common additional schillen. more a moree of session of jobs in surilary. we stake our tax ownfiran policy are looking they have no inten
# ----- Diversity: 1.2
# ----- Generating with seed: "r enormous engine of production. our pro"
# r enormous engine of production. our programs, barroly thing for eracted hansy.seclet, reinforement end, land, but we will included because i ask accerscoundenal pound.to reatest grouth and mefeactic reidension.we will appolement throughoret confidenclu and subumining recommend that for housing, and as they also kept a great precious 000 of the largest pertanted sources in vergra and troopponaces with a unifertant has proud to souther a
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 328s 66ms/step - loss: 1.1303
# Epoch 26/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1277
# ----- Generating text after Epoch: 25
# ----- Diversity: 0.2
# ----- Generating with seed: "man freedom in a world of peace.let us b"
# man freedom in a world of peace.let us bring the future of the congress and the program to active to the fact to continue to be a service of the congress and the congress and the congress to continue to protect the family of the historic community to ensure the congress and the program of the first time which will start the program to provide the congress to ready the principle of the fiscal year 1947. the advisory of the congress to co
# ----- Diversity: 0.5
# ----- Generating with seed: "man freedom in a world of peace.let us b"
# man freedom in a world of peace.let us be to continue to our country in congress and provided and our country in the foundations of the states of the present people than every of you and to religious free world and confidence in a continuing a new congress a helping families of the american principles of the congress to live and continue to make continues to assure this free of expenditures for this year in all of you to the home of ame
# ----- Diversity: 1.0
# ----- Generating with seed: "man freedom in a world of peace.let us b"
# man freedom in a world of peace.let us be research by leaders, and earching. and they arer from human united states savan, and in federagy discussion. this congress vasion level.of well-cutting able our economic scourged spending million dollars to every maintainiaged far opend in the free entrorim of diverse together rights of congressional future than 10,000 leader could better, repibit by this congress in of its growth in working on
# ----- Diversity: 1.2
# ----- Generating with seed: "man freedom in a world of peace.let us b"
# man freedom in a world of peace.let us brisk the - for a high loans of using splenserstop's country it the striespocoun will ba graval interests have beguninest, and any problem for build and openobible world time ir no rightlyre senior need nuclear threech -per-beforching than our people, and were our communities in out the nations, our policy. a graw with the next part and -selops and more seeftic must have morec women the syugon kill
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 333s 67ms/step - loss: 1.1277
# Epoch 27/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1251
# ----- Generating text after Epoch: 26
# ----- Diversity: 0.2
# ----- Generating with seed: "course, we can't do everything. but wher"
# course, we can't do everything. but where the program of the state of the union is the responsibility of the world in the world is the first time to reduce the last year in a state of the union is a program to the congress and the american people and the world the state of the union is a tax cut in the world that the program of the congress and the congress and the congress and the many of the congress and the congress and expanding the
# ----- Diversity: 0.5
# ----- Generating with seed: "course, we can't do everything. but wher"
# course, we can't do everything. but where additional state of this enemies of the larger communities and better to get an important future will be defense to state of the american people that work and to come of the leadership of the united states among the substantial demands of the past year to all these of the areas of the congress and the things. the difference in the community we have to be a year of the congress to the state of th
# ----- Diversity: 1.0
# ----- Generating with seed: "course, we can't do everything. but wher"
# course, we can't do everything. but where i recommend a campaign cotterislf. revisiong force with this advance iraquic demands on go tax reolong do. of message, but vietnams, and that they jobber to enterican we sens the contineent time to energue as our freders, purchasely clear to independent history. but the agreement of the side comprehensive shared of the united states collection of our paince and were small instive they and we fel
# ----- Diversity: 1.2
# ----- Generating with seed: "course, we can't do everything. but wher"
# course, we can't do everything. but where which refared rotiets. the any sharsion has now, peal backing on the program can stand now, isheets, tix reveral effort. zasio, in the relations are a comprehensive us are. 20 selfor the drade for altoricals, democratic for future to meets act, buraker- inearty, we've got to grount communitiral avoider their  recommendations retahents of the security outessimf our important that the un the mrson
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 335s 67ms/step - loss: 1.1251
# Epoch 28/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1225
# ----- Generating text after Epoch: 27
# ----- Diversity: 0.2
# ----- Generating with seed: "ity of the marketplace in the service of"
# ity of the marketplace in the service of the congress to the people of the united states of the first and the world that the state of the union is a state of the union is the democratic and the state of the union is a strong and community of the community of the states of the people of the world in the state of the union is the department of the united states and the state of the union is a strong and community programs of the state of
# ----- Diversity: 0.5
# ----- Generating with seed: "ity of the marketplace in the service of"
# ity of the marketplace in the service of the american people and the truly program in the last that to defense program will be a community in the hope of the world effort of the last the national activities that expect and economic and strong and competitive supporting the great optimical defense of the last year for the negotial of the state of the united states, and we seek to make the seavine, the things to the state of the union is
# ----- Diversity: 1.0
# ----- Generating with seed: "ity of the marketplace in the service of"
# ity of the marketplace in the service of pruces on our stands to relo4-thance to the state of the uncoment sign or your age of the same devalan the people'sl evil mind, the simple three power in their capable for schools, and now based recombal places hold that use their  this progress rundmentard to intogeted that the princ of the around district desire to gas estimate basic attacks, health care compased exeeftt forces and policy and p
# ----- Diversity: 1.2
# ----- Generating with seed: "ity of the marketplace in the service of"
# ity of the marketplace in the service of the condictratures about the value leadersfact prokents of lobbarely revolution, alread cregiving one cause valuration will in apperition to strang--and makis a progress any terms of othersed with, coriptions with the deficit (gallshhipsion, it shall give alcraqually, and who bring for eliminating smalls. underented to the fatol for whathk this we have workedly, dollar lives and cumpey a must, hi
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 340s 68ms/step - loss: 1.1225
# Epoch 29/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1201
# ----- Generating text after Epoch: 28
# ----- Diversity: 0.2
# ----- Generating with seed: "by as much as 14 percent, start a new wa"
# by as much as 14 percent, start a new way to be a service of the congress and the security of the congress and the congress and the state of the union is the first time of the security of the congress and the security of the federal government should be defense and community to the security of the congress and the state of the union that the security of our country to the congress on the security of the congress and the state of the uni
# ----- Diversity: 0.5
# ----- Generating with seed: "by as much as 14 percent, start a new wa"
# by as much as 14 percent, start a new ways of the congress and the time to make the nation that the middle east and all our children and the strength of american in the congress that and the proposing the fiscal year 1947 for a confidence and weapons and we can aid the living of the free needed for congress in the congress and the people of the government has been the first responsibility and bill for the congress raise the world. i am
# ----- Diversity: 1.0
# ----- Generating with seed: "by as much as 14 percent, start a new wa"
# by as much as 14 percent, start a new was. deetscapt vietnam, to proed to restone haw its community to the peoplement actly responsible.. tonight i compoled by and college.now, what it. realized demaccess other turn to the art's 50 countriesch-orter nations are sipplimated stronger taxes very sectoted which can be saddrities and some world taxes prohised by one of our demandrused. and this domesticm, of prices, and i want to proced peac
# ----- Diversity: 1.2
# ----- Generating with seed: "by as much as 14 percent, start a new wa"
# by as much as 14 percent, start a new way-gialn a crubic or, and once and other people amort, the perentive is the alliance will good man help.this program, the knowly of a bepasses.in a security in treafly child cape choicing super, america but this issue what most chomiclies, and if our income is tonight, chiid prosperous determining our efforts to put every night, eres for fear and emportionare from payments in governmult, and penisc
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 340s 68ms/step - loss: 1.1201
# Epoch 30/30
# 4989/4990 [============================>.] - ETA: 0s - loss: 1.1177
# ----- Generating text after Epoch: 29
# ----- Diversity: 0.2
# ----- Generating with seed: "ho met with our scientists at geneva in "
# ho met with our scientists at geneva in the congress and the people of the united nations and the program to the most problem of the congress on the state of the union of the united states and the congress on the state of the united states and the state of the united states and the state of the union of the past year and the program to continue to continue to the most proposals of the first to the substantial economic standards of the f
# ----- Diversity: 0.5
# ----- Generating with seed: "ho met with our scientists at geneva in "
# ho met with our scientists at geneva in their families and strengthened the congress on the congress and every construct of the world will stop the only way to reduce the state of the problem of the federal government and the most of these districts authorize this police and continue to provide the shapper and the trade to see that the further strength and our nation to have the tax cledy to the same vital standards of free nations in t
# ----- Diversity: 1.0
# ----- Generating with seed: "ho met with our scientists at geneva in "
# ho met with our scientists at geneva in theiscen them and freedom of possible.fellenss more substantial employees from tho pation threated by facistnically escaner the services against any of i world. for their ozjent--are depresingens you continue to continues that the safence age flex, increasess forced control caftion the it.an our children of great and growth together. threatened we have havings in messions. in our planfists. ind th
# ----- Diversity: 1.2
# ----- Generating with seed: "ho met with our scientists at geneva in "
# ho met with our scientists at geneva in offectively ult.  her as innepoly opportulion has varo.  yet araquees american.fen mind. sthan patarousef, holdop balance will now communation have afraiding not ballister, bring lobbers.need manoupard it -- our chegy irant-hutge,   yously now is to drawing murule nave kfortay voluterns. in the mid-maming through yet tax by treaty alaqkay. .ugher ever many pay. and iraq leadorth.i would sid these
# WARNING:tensorflow:Can save best model only with val_loss available, skipping.
# 4990/4990 [==============================] - 341s 68ms/step - loss: 1.1177

# %%
model.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_5 (LSTM)                (None, 128)               95232
# _________________________________________________________________
# dense_3 (Dense)              (None, 57)                7353
# =================================================================
# Total params: 102,585
# Trainable params: 102,585
# Non-trainable params: 0
# _________________________________________________________________

# %%
test_list = list('s multibillion-dollar package that will be a congress and the social security program and providing services. the past of the economy of freedom of the congress for all our competitive and controls on the soviet union can only any medicare on the world. we must continue the artalically and good to the sate community of the security of our communities are a peace in the united states are on the expenditures of congress and happened in an')
len(test_list)
# Out:
# 440

# %%
# To continue training...
model.load_weights("saved_weights.hdf5")

model.fit(x, y,
          batch_size=128,
          epochs=30,
          callbacks=[print_callback, checkpointer])
